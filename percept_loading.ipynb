# %%
# import json files 
import json as js
import numpy as np
import pandas
import matplotlib.pyplot as plt

# %%
#load json file

file_path = r"C:\Users\fkamdar\Desktop\Percept\testing_data\Report_Json_Session_Report_20250903T170810.json"
data = js.load(open(file_path))

# %%
data
# Out:
# {'DataVersion': '1.3',
#  'AbnormalEnd': False,
#  'FullyReadForSession': True,
#  'ReadAllStatus': 'COMPLETED',
#  'FeatureInformationCode': '60d',
#  'SessionDate': '2025-09-02T15:35:18Z',
#  'SessionEndDate': '2025-09-02T16:46:42Z',
#  'ProgrammerTimezone': 'Pacific Daylight Time',
#  'ProgrammerTimezoneId': 'America/Los_Angeles',
#  'ProgrammerUtcOffset': '-07:00',
#  'ProgrammerLocale': 'en_US',
#  'ProgrammerVersion': '5.0.780',
#  'PatientInformation': {'Initial': {'PatientFirstName': 'â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆ',
#    'PatientLastName': 'â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆ',
#    'PatientGender': 'â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆ',
#    'PatientDateOfBirth': 'â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆ',
#    'PatientId': 'â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆ',
#    'ClinicianNotes': '',
#    'Diagnosis': 'DiagnosisTypeDef.ParkinsonsDisease'},
#   'Final': {'PatientFirstName': 'â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆ',
#    'PatientLastName': 'â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆ',
#    'PatientGender': 'â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆ',
# ...

# %%
# load json file as a pandas dataframe
df = pandas.json_normalize(data)
df.head()
# Out:
#   DataVersion  AbnormalEnd  FullyReadForSession ReadAllStatus  \
# 0         1.3        False                 True     COMPLETED
#
#   FeatureInformationCode           SessionDate        SessionEndDate  \
# 0                    60d  2025-09-02T15:35:18Z  2025-09-02T16:46:42Z
#
#       ProgrammerTimezone ProgrammerTimezoneId ProgrammerUtcOffset  ...  \
# 0  Pacific Daylight Time  America/Los_Angeles              -07:00  ...
#
#                              LeadConfiguration.Final  \
# 0  [{'Hemisphere': 'HemisphereLocationDef.Left', ...
#
#   Stimulation.InitialStimStatus Stimulation.FinalStimStatus  \
# 0              StimStatusDef.ON            StimStatusDef.ON
#
#                                       Groups.Initial  \
# 0  [{'GroupId': 'GroupIdDef.GROUP_A', 'GroupName'...
#
#                                         Groups.Final BatteryReminder.Enabled  \
# 0  [{'GroupId': 'GroupIdDef.GROUP_B', 'GroupName'...                   False
#
# ...
